# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
link = "https://maps-cartes.services.geo.ca/server_serveur/rest/services/NRCan/historical_flood_event_en/MapServer/0?f=pjson"
data_api = requests.get(link)
data_api
data = data_api.text

# %%
json_data = json.loads(data)

# %%
df = pd.json_normalize(json_data)
df
# Out:
#    currentVersion  id                     name           type  \
# 0           10.81   0  Historical Flood Events  Feature Layer
#
#                                          description            geometryType  \
# 0  Representation of the causes of flooding event...  esriGeometryMultipoint
#
#                                        copyrightText parentLayer subLayers  \
# 0  Government of Canada; Natural Resources Canada...        None        []
#
#    minScale  ...  advancedQueryCapabilities.supportsStatistics  \
# 0         0  ...                                          True
#
#    advancedQueryCapabilities.supportsHavingClause  \
# 0                                            True
#
#    advancedQueryCapabilities.supportsCountDistinct  \
# 0                                             True
#
#   advancedQueryCapabilities.supportsOrderBy  \
# 0                                      True
#
#   advancedQueryCapabilities.supportsDistinct  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 82 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   currentVersion                                             1 non-null      float64
#  1   id                                                         1 non-null      int64
#  2   name                                                       1 non-null      object
#  3   type                                                       1 non-null      object
#  4   description                                                1 non-null      object
#  5   geometryType                                               1 non-null      object
#  6   copyrightText                                              1 non-null      object
#  7   parentLayer                                                0 non-null      object
# ...

# %%
https://www.mdpi.com/2076-3417/13/7/4322
