# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/usa_incident_gas_distribution_jan2010_present.csv", encoding='latin')
data
# Out:
#      REPORT_RECEIVED_DATE  IYEAR  REPORT_NUMBER  SUPPLEMENTAL_NUMBER  \
# 0               7/27/2023   2023       20230039                38330
# 1               7/20/2023   2023       20230036                38292
# 2               7/25/2023   2023       20230038                38316
# 3               7/21/2023   2023       20230037                38299
# 4               7/14/2023   2023       20230035                38272
# ...                   ...    ...            ...                  ...
# 1388           11-04-2011   2010       20110378                15341
# 1389            3/31/2010   2010       20100013                15189
# 1390           10/21/2010   2010       20100087                15877
# 1391           05-10-2010   2010       20100022                15025
# 1392            7/20/2010   2010       20100057                15073
#
#              REPORT_TYPE  OPERATOR_ID                                   NAME  \
# 0         ORIGINAL FINAL         2596               COLUMBIA GAS OF OHIO INC
# 1               ORIGINAL        32074         SUMMIT NATURAL GAS OF MISSOURI
# 2               ORIGINAL        12390        METROPOLITAN UTILITIES DISTRICT
# 3               ORIGINAL        13710               NORTHERN ILLINOIS GAS CO
# 4         ORIGINAL FINAL        31348     ATMOS ENERGY CORPORATION - MID-TEX
# ...                  ...          ...                                    ...
# 1388            ORIGINAL         1640                          BOSTON GAS CO
# 1389  SUPPLEMENTAL FINAL        13710               NORTHERN ILLINOIS GAS CO
# 1390  SUPPLEMENTAL FINAL        11032                         LACLEDE GAS CO
# 1391      ORIGINAL FINAL        15007              PACIFIC GAS & ELECTRIC CO
# 1392            ORIGINAL         4473  ATMOS ENERGY CORPORATION - WEST TEXAS
#
#      LOCATION_STATE_ABBREVIATION LOCATION_POSTAL_CODE  LOCATION_LATITUDE  ...  \
# 0                             OH                43055          40.066307  ...
# 1                             MO                65711          37.131840  ...
# 2                             NE                68114          41.248784  ...
# 3                             IL                61084          41.807436  ...
# 4                             TX                76108          32.778159  ...
# ...                          ...                  ...                ...  ...
# 1388                          MA                 2451          42.368815  ...
# 1389                          IL                60120          42.061370  ...
# 1390                          MO                63138          38.771120  ...
# 1391                          CA                95501          40.773200  ...
# 1392                          TX           79102-0000          35.231530  ...
#
#       PREPARER_TELEPHONE PREPARER_FAX LOCAL_CONTACT_NAME  \
# 0         1-614-460-5491          NaN       ROB R. SMITH
# 1           417-349-0512          NaN     JORDAN SLAYTON
# 2             4025047108          NaN                NaN
# 3                    NaN          NaN                NaN
# 4           469-261-2011          NaN        STEVE KLEIN
# ...                  ...          ...                ...
# 1388          7819071854   7819075701                NaN
# 1389        630-388-2316          NaN                NaN
# 1390          3146585413   3145355075                NaN
# 1391          9259744313          NaN                NaN
# 1392          8067984423   8067984495                NaN
#
#                 LOCAL_CONTACT_EMAIL LOCAL_CONTACT_TELEPHONE  \
# 0              rrsmith@nisource.com          1-614-460-5491
# 1     jslayton@summitnaturalgas.com            417-349-0512
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4     william.klein@atmosenergy.com            469-261-2011
# ...                             ...                     ...
# 1388                            NaN                     NaN
# 1389                            NaN                     NaN
# 1390                            NaN                     NaN
# 1391                            NaN                     NaN
# 1392                            NaN                     NaN
#
#           AUTHORIZER_NAME                                   AUTHORIZER_TITLE  \
# 0            ROB R. SMITH  MANAGER OF OPERATIONS COMPLIANCE- RISK MANAGEMENT
# 1            MITCH PEBLEY                  DIRECTOR OF OPERATIONS - MISSOURI
# 2           TYSON ROBARDS                                    CLAIMS ADJUSTER
# 3         LETICIA QUEZADA                          MANAGER COMPLIANCE AND QA
# 4            JEFF KNIGHTS                        SR. V.P. TECHNICAL SERVICES
# ...                   ...                                                ...
# 1388  CHRISTOPHER ARONSON                                     SENIOR COUNSEL
# 1389      LETICIA QUEZADA                      MANAGER REGULATORY COMPLIANCE
# 1390    CRAIG R HOEFERLIN        ASSISTANT VP ENGINEERING AND FIELD SERVICES
# 1391    LAURENCE DENISTON                                    PROGRAM MANAGER
# 1392        RIC KISSINGER                              VP TECHNICAL SERVICES
#
#      AUTHORIZER_TELEPHONE                  AUTHORIZER_EMAIL  \
# 0          1-614-460-5491              rrsmith@nisource.com
# 1            303-889-9455       mpebley@summitutilities.com
# 2              4025047108         tyson_robards@mudnebr.com
# 3              6305142036            lquezad@southernco.com
# 4            214-206-2701      jeff.knights@atmosenergy.com
# ...                   ...                               ...
# 1388           7819071854  christopher.aronson@us.ngrid.com
# 1389         630-388-2316                 lquezad@nicor.com
# 1390           3146585410         choeferlin@lacledegas.com
# 1391           9259744313                      lcd1@pge.com
# 1392           8067984432     ric.kissinger@atmosenergy.com
#
#                                               NARRATIVE
# 0     ON JUNE 26, 2023, A ROADWAY MILLING CONTRACTOR...
# 1     ON JUNE 26TH, 2023, A&A CABLE WAS INSTALLING A...
# 2     FOLLOWING A SERVICE VALVE REPLACEMENT, ENVIRON...
# 3     THE STRUCTURE WHERE THE EXPLOSION OCCURRED IS ...
# 4     ON JUNE 14, 2023, AT APPROXIMATELY 6:12 PM, AN...
# ...                                                 ...
# 1388                                                NaN
# 1389  NATURAL GAS FROM CRACKED STEEL MAIN MIGRATED I...
# 1390  A 2-INCH STEEL NATURAL GAS MAIN WAS EXPOSED IN...
# 1391  ON 1/19/10 AT APPROXIMATELY 1627 HOURS A 6.5 M...
# 1392  NATURAL GAS LEAKAGE DUE TO CORROSION MIGRATED ...
#
# [1393 rows x 456 columns]

# %%
df_map = data[['REPORT_NUMBER','LOCATION_LATITUDE', 'LOCATION_LONGITUDE']]
df_map
# Out:
#       REPORT_NUMBER  LOCATION_LATITUDE  LOCATION_LONGITUDE
# 0          20230039          40.066307          -82.417776
# 1          20230036          37.131840          -92.263810
# 2          20230038          41.248784          -96.034527
# 3          20230037          41.807436          -88.195612
# 4          20230035          32.778159          -97.475498
# ...             ...                ...                 ...
# 1388       20110378          42.368815          -71.239223
# 1389       20100013          42.061370          -88.263030
# 1390       20100087          38.771120          -90.229290
# 1391       20100022          40.773200         -124.152800
# 1392       20100057          35.231530         -101.816510
#
# [1393 rows x 3 columns]

# %%
# data[data['CAUSE'] == 'NATURAL FORCE DAMAGE'].value_counts()
data[data['CAUSE'] == 'NATURAL FORCE DAMAGE']['CAUSE_DETAILS']
# Out:
# 16                    SNOW/ICE IMPACT OR ACCUMULATION
# 19                    SNOW/ICE IMPACT OR ACCUMULATION
# 23                    SNOW/ICE IMPACT OR ACCUMULATION
# 30                                 HEAVY RAINS/FLOODS
# 73                                         HIGH WINDS
#                             ...
# 1367                                      TEMPERATURE
# 1370                       OTHER NATURAL FORCE DAMAGE
# 1384                                      TEMPERATURE
# 1387    EARTH MOVEMENT, NOT DUE TO HEAVY RAINS/FLOODS
# 1391    EARTH MOVEMENT, NOT DUE TO HEAVY RAINS/FLOODS
# Name: CAUSE_DETAILS, Length: 100, dtype: object
